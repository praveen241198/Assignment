# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ## Praveen M
#
# Data Science Asprint

# %% [markdown]
# *I am interested in data science because I love to work with data*

# %% [markdown]
# ### The following code gives subsrtaction

# %%
a=10
b=5
sub = a-b
print(sub)
# Out:
# 5

# %% [markdown]
# 1.[Link to this cousee](https://in.coursera.org/learn/open-source-tools-for-data-science)
#
# > This is the course that tells you the various tools for data Science.
# > It Includes Jupyter,Rstudio,IBM watson etc.
